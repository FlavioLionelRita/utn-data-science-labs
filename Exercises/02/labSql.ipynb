# %% [markdown]
# # Lab SQL
#
# ## Requirements
#
# execute the following command to install the required packages:
#
# ```bash
# pip install -r requirements.txt
# ```

# %%
"""Import csv files to sqlite3 database"""
import sqlite3
import pandas

conn = sqlite3.connect('courses.db')
# read csv files
courses = pandas.read_csv('Courses.csv', sep=',' , encoding='ISO-8859-1')
teachers = pandas.read_csv('Teachers.csv', sep=',' , encoding='ISO-8859-1')
students = pandas.read_csv('Students.csv', sep=',' , encoding='ISO-8859-1')
students_courses = pandas.read_csv('Students_Courses.csv', sep=',' , encoding='ISO-8859-1')
# create tables
courses.to_sql('TBL_COURSES', conn, index=False, if_exists='replace')
teachers.to_sql('TBL_TEACHERS', conn, index=False, if_exists='replace')
students.to_sql('TBL_STUDENTS', conn, index=False, if_exists='replace')
students_courses.to_sql('TBL_STUDENTS_COURSES', conn, index=False, if_exists='replace')
conn.close()

# %%
"""Queries"""

print('Cuántos cursos diferentes hay:')
conn = sqlite3.connect('courses.db')
cursor = conn.cursor()
cursor.execute('SELECT COUNT(DISTINCT Curso) AS COURSES FROM TBL_COURSES')
result = cursor.fetchall()
for row in result:
    print(row)

print('Cuántos alumnos hay en cada curso:')    
query = '''
SELECT c.CURSO, COUNT(DISTINCT SC.EstudianteID) AS STUDENTS 
FROM TBL_STUDENTS_COURSES as SC
INNER JOIN TBL_COURSES as C ON SC."Curso ID" = C."Curso ID"
GROUP BY C.CURSO
'''
cursor.execute(query)
result = cursor.fetchall()
for row in result:
    print(row)    
print('Determinar a partir de la respuesta anterior cuál es el curso más popular:')
query = '''
SELECT c.CURSO, COUNT(DISTINCT SC.EstudianteID) AS STUDENTS 
FROM TBL_STUDENTS_COURSES as SC
INNER JOIN TBL_COURSES as C ON SC."Curso ID" = C."Curso ID"
GROUP BY C.CURSO
HAVING STUDENTS = (
    SELECT MAX(STUDENTS) AS MAX_STUDENTS
    FROM (
        SELECT c.CURSO, COUNT(DISTINCT SC.EstudianteID) AS STUDENTS 
        FROM TBL_STUDENTS_COURSES as SC
        INNER JOIN TBL_COURSES as C ON SC."Curso ID" = C."Curso ID"
        GROUP BY C.CURSO
        )
    )
'''
print('De ese curso más popular extraer la lista de alumnos:')
query = '''
SELECT C.CURSO, S.Name AS STUDENT
FROM TBL_STUDENTS as S
INNER JOIN TBL_STUDENTS_COURSES as SC ON S.EstudianteID = SC.EstudianteID
INNER JOIN TBL_COURSES AS C ON SC."Curso ID" = C."Curso ID"
INNER JOIN (
    SELECT SC."Curso ID" AS Curso_ID, COUNT(DISTINCT SC.EstudianteID) AS STUDENTS 
    FROM TBL_STUDENTS_COURSES as SC
    GROUP BY SC."Curso ID"
    HAVING STUDENTS = (
        SELECT MAX(STUDENTS)
        FROM (
            SELECT c.CURSO, COUNT(DISTINCT SC.EstudianteID) AS STUDENTS 
            FROM TBL_STUDENTS_COURSES as SC
            INNER JOIN TBL_COURSES as C ON SC."Curso ID" = C."Curso ID"
            GROUP BY C.CURSO
            )
        )
    ) as C ON SC."Curso ID" = C.Curso_ID
'''
cursor.execute(query)
result = cursor.fetchall()
for row in result:
    print(row)

print('Definir en función del año de ingreso cuántos años hace que esta cada estudiante en la universidad:')
query = '''
SELECT S.Name as STUDENT, S.FechaIngreso, strftime('%Y', 'now') - substr(S.FechaIngreso, length(S.FechaIngreso) - 3, 4) AS YEARS  
FROM TBL_STUDENTS AS S
'''
cursor.execute(query)
result = cursor.fetchall()
for row in result:
    print(row)

conn.close()
# Out:
# Cuántos cursos diferentes hay:
# (30,)
# Cuántos alumnos hay en cada curso:
# ('Animacion Audiovisual', 31)
# ('Arbitro de futbol', 8)
# ('Audio for Games', 50)
# ('Coaching Ontologico', 8)
# ('Compliance y lavado de dinero', 20)
# ('Comunicación de Directivos', 5)
# ('Curso de Liquidacion de Sueldos', 6)
# ('Data Science', 1)
# ('Debates de politica exterior', 42)
# ('Deep Learning', 3)
# ('Derecho penal ', 43)
# ('Desarrollo con Angular', 30)
# ('Director Tecnico de Futbol', 3)
# ('Economia para principiantes', 17)
# ('Empleabilidad de personas con discapacidad', 43)
# ('Gestion del Inversor Financiero', 1)
# ('Gestion del transporte', 8)
# ('Introducción al Idioma Japonés Técnico y Manga', 7)
# ('Liderazgo Estrategico', 5)
# ('Luminotecnia', 3)
# ('Marketing Digital', 4)
# ('Nutricion deportiva', 46)
# ('PNL', 29)
# ('Periodismo deportivo', 2)
# ('Power BI', 2)
# ('Programacion Web Inicial', 43)
# ('Psicologia aplicada a las ciencias del deporte', 1)
# ('SQL', 46)
# ('Seguridad Electrica', 6)
# ('UX', 28)
# Determinar a partir de la respuesta anterior cuál es el curso más popular:
# De ese curso más popular extraer la lista de alumnos:
# ('Audio for Games', 'Veronica Ramirez')
# ('Audio for Games', 'Leonela Perez')
# ('Audio for Games', 'Sebastian Marich')
# ('Audio for Games', 'Amanda Amaya')
# ('Audio for Games', 'Lucia Amancio')
# ('Audio for Games', 'Lucia Lopez')
# ('Audio for Games', 'Florencia Winter')
# ('Audio for Games', 'Marina Iigo')
# ('Audio for Games', 'Santiago Lopez')
# ('Audio for Games', 'Silvina Diaz')
# ('Audio for Games', 'Melisa Peretti')
# ('Audio for Games', 'Pedro Gomez')
# ('Audio for Games', 'Anita Benitez')
# ('Audio for Games', 'Olivia Rodrigo')
# ('Audio for Games', 'Brian Perez')
# ('Audio for Games', 'Flavia Gomez')
# ('Audio for Games', 'Solana Hidalgo')
# ('Audio for Games', 'Lorena Marich')
# ('Audio for Games', 'Silvana Diaz')
# ('Audio for Games', 'Ernesto Diaz')
# ('Audio for Games', 'Maico Andrada')
# ('Audio for Games', 'Hector Cena')
# ('Audio for Games', 'Martin Dominguez')
# ('Audio for Games', 'Wanda Suarez')
# ('Audio for Games', 'Simon Aguirre')
# ('Audio for Games', 'Nicolas Sattler')
# ('Audio for Games', 'Facundo Priatti')
# ('Audio for Games', 'Berta Arce')
# ('Audio for Games', 'Juan Banegas')
# ('Audio for Games', 'Lisandro Martinez')
# ('Audio for Games', 'Karen Homs')
# ('Audio for Games', 'Alba Martinez')
# ('Audio for Games', 'Sofia Pratto')
# ('Audio for Games', 'Carla Irigo')
# ('Audio for Games', 'Soraya Guevara')
# ('Audio for Games', 'Juan Pablo Martinez')
# ('Audio for Games', 'Paloma Rojas')
# ('Audio for Games', 'Walter Benitez')
# ('Audio for Games', 'Mariana Trifone')
# ('Audio for Games', 'Jazmin Benitez')
# ('Audio for Games', 'Narela Pompei')
# ('Audio for Games', 'Maria Acosta')
# ('Audio for Games', 'Martina Gonzalez')
# ('Audio for Games', 'Evelyn Soria')
# ('Audio for Games', 'Marcelo Fernandez')
# ('Audio for Games', 'Daiana Loza')
# ('Audio for Games', 'Josefina Marco')
# ('Audio for Games', 'Lucas Lemos')
# ('Audio for Games', 'Stefania Roitman')
# ('Audio for Games', 'Ayelen Candia')
# ('Audio for Games', 'Miguel Diaz')
# Definir en función del año de ingreso cuántos años hace que esta cada estudiante en la universidad:
# ('Veronica Ramirez', '11/21/2016', 8)
# ('Leonela Perez', '9/5/2015', 9)
# ('Sebastian Marich', '6/1/2016', 8)
# ('Amanda Amaya', '7/31/2015', 9)
# ('Lucia Amancio', '6/15/2015', 9)
# ('Lucia Lopez', '2/15/2017', 7)
# ('Lautaro Martinez', '1/1/2016', 8)
# ('Hector Peretti', '7/28/2015', 9)
# ('Horacio Rodriguez', '12/4/2016', 8)
# ('Lauriana Esposito', '5/17/2016', 8)
# ('Fabricio Arce', '7/17/2016', 8)
# ('Maria Zabala', '10/10/2015', 9)
# ('Romina Gusti', '4/3/2015', 9)
# ('Fernando Ulloa', '8/30/2016', 8)
# ('Walter Estevez', '5/12/2016', 8)
# ('Florencia Winter', '3/10/2016', 8)
# ('Marina Iigo', '9/23/2016', 8)
# ('Santiago Lopez', '9/15/2015', 9)
# ('Silvina Diaz', '1/6/2016', 8)
# ('Melisa Peretti', '11/2/2016', 8)
# ('Pedro Gomez', '2/3/2016', 8)
# ('Anita Benitez', '2/18/2017', 7)
# ('Roberto Cesar', '1/19/2016', 8)
# ('Exequiel Benegas', '8/4/2016', 8)
# ('Hector Lopez', '3/19/2015', 9)
# ('Ricardo Martinez', '12/23/2015', 9)
# ('Julian Alvarez', '12/28/2015', 9)
